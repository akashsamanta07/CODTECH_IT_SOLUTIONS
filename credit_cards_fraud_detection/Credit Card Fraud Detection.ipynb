# Out:
#              V1        V2        V3        V4        V5        V6        V7  \
# 12468 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494 -0.882850
# 12469  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536 -1.413170
# 12470 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346 -2.234739
# 12471 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548 -2.208002
# 12472  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695  0.223050
#
#              V8        V9       V10       V11       V12       V13       V14  \
# 12468  0.697211 -2.064945 -5.587794  2.115795 -5.417424 -1.235123 -6.665177
# 12469  0.248525 -1.127396 -3.232153  2.858466 -3.096915 -0.792532 -5.210141
# 12470  1.210158 -0.652250 -3.463891  1.794969 -2.775022 -0.418950 -4.057162
# 12471  1.058733 -1.632333 -5.245984  1.933520 -5.030465 -1.127455 -6.416628
# 12472 -0.068384  0.577829 -0.888722  0.491140  0.728903  0.380428 -1.948883
#
#             V15       V16       V17       V18       V19       V20       V21  \
# 12468  0.401701 -2.897825 -4.570529 -1.315147  0.391167  1.252967  0.778584
# 12469 -0.613803 -2.155297 -3.267116 -0.688505  0.737657  0.226138  0.370612
# 12470 -0.712616 -1.603015 -5.035326 -0.507000  0.266272  0.247968  0.751826
# 12471  0.141237 -2.549498 -4.614717 -1.478138 -0.035480  0.306271  0.583276
# 12472 -0.832498  0.519436  0.903562  1.197315  0.593509 -0.017652 -0.164350
#
#             V22       V23       V24       V25       V26       V27       V28  \
# 12468 -0.319189  0.639419 -0.294885  0.537503  0.788395  0.292680  0.147968
# 12469  0.028234 -0.145640 -0.081049  0.521875  0.739467  0.389152  0.186637
# 12470  0.834108  0.190944  0.032070 -0.739695  0.471111  0.385107  0.194361
# 12471 -0.269209 -0.456108 -0.183659 -0.328168  0.606116  0.884876 -0.253700
# 12472 -0.295135 -0.072173 -0.450261  0.313267 -0.289617  0.002988 -0.015309
#
#          Amount  Class
# 12468  1.206024      1
# 12469 -0.350191      1
# 12470 -0.041818      1
# 12471  0.626302      1
# 12472 -0.183191      1

# %%
data.shape
# Out:
# (12473, 30)

# %%
print("Number of columns: {}".format(data.shape[1]))
print("Number of rows: {}".format(data.shape[0]))
# Out:
# Number of columns: 30
# Number of rows: 12473

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12473 entries, 0 to 12472
# Data columns (total 30 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   V1      12473 non-null  float64
#  1   V2      12473 non-null  float64
#  2   V3      12473 non-null  float64
#  3   V4      12473 non-null  float64
#  4   V5      12473 non-null  float64
#  5   V6      12473 non-null  float64
#  6   V7      12473 non-null  float64
#  7   V8      12473 non-null  float64
#  8   V9      12473 non-null  float64
#  9   V10     12473 non-null  float64
#  10  V11     12473 non-null  float64
#  11  V12     12473 non-null  float64
#  12  V13     12473 non-null  float64
#  13  V14     12473 non-null  float64
#  14  V15     12473 non-null  float64
#  15  V16     12473 non-null  float64
#  16  V17     12473 non-null  float64
#  17  V18     12473 non-null  float64
#  18  V19     12473 non-null  float64
#  19  V20     12473 non-null  float64
#  20  V21     12473 non-null  float64
#  21  V22     12473 non-null  float64
#  22  V23     12473 non-null  float64
#  23  V24     12473 non-null  float64
#  24  V25     12473 non-null  float64
#  25  V26     12473 non-null  float64
#  26  V27     12473 non-null  float64
#  27  V28     12473 non-null  float64
#  28  Amount  12473 non-null  float64
#  29  Class   12473 non-null  int64
# dtypes: float64(29), int64(1)
# memory usage: 2.9 MB

# %%
data.isnull().sum()
# Out:
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
sc = StandardScaler()
#
#         V15       V16       V17       V18       V19       V20       V21  \
# 0 -0.163349 -1.685756 -0.066499  0.573899 -0.530319 -0.401314 -0.492079
# 1  0.621141  0.520071 -1.640671  0.052541 -0.637632  0.164365 -0.339715
# 2 -0.662502  0.277232 -0.607122  0.738573  0.404569 -0.138601  0.034223
# 3  0.863741  0.913992  0.462846  0.640997 -0.195535 -0.882676 -0.058211
# 4 -0.387200 -1.337366  0.806814 -0.605519  0.845985  0.269220  0.013993
#
#         V22       V23       V24       V25       V26       V27       V28  \
# 0 -1.020396  0.237618  0.575588 -0.193168  0.447422 -0.087935 -0.044387
# 1 -0.718890 -0.098622  0.932313 -0.212149 -0.936115 -0.705489 -0.574254
# 2  0.285358  0.107987 -0.021356  0.026749 -0.445084  0.032410  0.027787
# 3  0.389596  0.133162 -0.060695 -1.224341  0.049724 -0.623551  0.659576
# 4  0.421238 -0.092316  0.118036 -0.020478 -0.153657  0.435286  0.209789
#
#      Amount  Class
# 0 -0.019115      0
# 1 -0.151342      0
# 2 -0.245872      0
# 3 -0.097062      0
# 4 -0.226002      0

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data.shape
# Out:
# (12473, 30)

# %%
data['Class'].value_counts()
# Out:
# Class
# 0    12000
# 1      473
# Name: count, dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
plt.pie(data['Class'].value_counts())
plt.title("Transcation")
plt.legend(["no Fraud","Fraud"])
plt.show()

# %%
x = data.drop('Class', axis = 1)
y=data['Class']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)

# %%
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score

# %%
classifier = {
    "Logistic Regression": LogisticRegression(),
    "Decision Tree Classifier": DecisionTreeClassifier(),
    "RandomForestClassifier" : RandomForestClassifier()
}
for name, clf in classifier.items():
    print(f"\n=========={name}===========")
    clf.fit(x_train, y_train)
    y_pred = clf.predict(x_test)
    print(f"\n Accuaracy: {accuracy_score(y_test, y_pred)}")
    print(f"\n Precision: {precision_score(y_test, y_pred)}")
    print(f"\n Recall: {recall_score(y_test, y_pred)}")
    print(f"\n F1 Score: {f1_score(y_test, y_pred)}")
# Out:
# ==========Logistic Regression===========
#
#  Accuaracy: 0.9875751503006012
#
#  Precision: 0.9506172839506173
#
#  Recall: 0.7403846153846154
#
#  F1 Score: 0.8324324324324325
#
# ==========Decision Tree Classifier===========
#
#  Accuaracy: 0.9855711422845691
#
#  Precision: 0.8777777777777778
#
#  Recall: 0.7596153846153846
#
#  F1 Score: 0.8144329896907216
#
# ==========RandomForestClassifier===========
#
#  Accuaracy: 0.9891783567134268
#
#  Precision: 0.9753086419753086
#
#  Recall: 0.7596153846153846
#
#  F1 Score: 0.8540540540540541

# %%
normal = data[data['Class']==0]
fraud = data[data['Class']==1]

# %%
normal.shape
# Out:
# (12000, 30)

# %%
fraud.shape
# Out:
# (473, 30)

# %%
normal_sample = normal.sample(n=1000)

# %%
normal_sample.shape
# Out:
# (1000, 30)

# %%
new_data = pd.concat([normal_sample,fraud], ignore_index=True)

# %%
new_data.head()
# Out:
#          V1        V2        V3        V4        V5        V6        V7  \
# 0 -0.863968  1.011437  1.834507  0.678632  0.004776  0.536075  0.486273
# 1 -1.711871  1.489682  1.450696  0.772359 -0.620413  0.075372 -0.294961
# 2 -1.420175  0.302981  0.181291  1.203453  3.457226  3.639705  0.612507
# 3  1.369663 -0.527794 -0.029469 -0.957426 -0.406009 -0.017528 -0.441057
# 4 -1.268100  1.734260  0.119184 -0.222497 -0.100413 -0.269813 -0.067585
#
#          V8        V9       V10       V11       V12       V13       V14  \
# 0  0.290357 -0.576714  0.015533  0.867869 -0.615162 -2.147549  0.782868
# 1  1.097543 -1.124591 -0.459726  1.491153  1.269191  0.479295  0.893843
# 2  0.535345 -1.521703  0.863644 -0.259516 -0.778163 -0.058328  0.180072
# 3 -0.099013 -1.241597  0.790100  0.424465  0.923276  1.880447 -0.066245
# 4  0.942421 -0.861297 -0.506809  0.580049  1.085537  1.120844  0.117064
#
#         V15       V16       V17       V18       V19       V20       V21  \
# 0  1.064483  0.031289 -0.190754  0.302004  0.639964 -0.147444 -0.164534
# 1  0.840111  0.055195  0.159350  0.062152  0.337350 -0.016607  0.019417
# 2  0.839876  0.376684 -0.878251  0.226116  0.458903 -0.181547 -0.208951
# 3  0.201538 -0.704034 -0.829255  1.562305 -0.050447 -0.267797 -0.477297
# 4  0.109807  1.022419 -0.275993  0.599705  0.479324  0.109449 -0.207814
#
#         V22       V23       V24       V25       V26       V27       V28  \
# 0 -0.696992 -0.102347 -0.408343 -0.041733 -0.527684 -0.168681  0.058099
# 1 -0.178836  0.006704  0.203317  0.112757 -0.483012 -0.007675 -0.040434
# 2 -0.218947  0.267332  0.999668  0.730415  0.143986 -0.175252 -0.292014
# 3 -0.944974 -0.058944 -0.790590  0.257774  0.951301 -0.057021 -0.002218
# 4 -0.718849 -0.039039 -0.567296  0.047914  0.114818  0.116578 -0.002400
#
#      Amount  Class
# 0 -0.167612      0
# 1 -0.223196      0
# 2 -0.164352      0
# 3 -0.161235      0
# 4 -0.234534      0

# %%
new_data['Class'].value_counts()
# Out:
# Class
# 0    1000
# 1     473
# Name: count, dtype: int64

# %%
x = new_data.drop('Class', axis = 1)
y= new_data['Class']

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2, random_state = 42)

# %%
classifier = {
    "Logistic Regression": LogisticRegression(),
    "Decision Tree Classifier": DecisionTreeClassifier(),
    "RandomForestClassifier" : RandomForestClassifier()
}
for name, clf in classifier.items():
    print(f"\n=========={name}===========")
    clf.fit(x_train, y_train)
    y_pred = clf.predict(x_test)
    print(f"\n Accuaracy: {accuracy_score(y_test, y_pred)}")
    print(f"\n Precision: {precision_score(y_test, y_pred)}")
    print(f"\n Recall: {recall_score(y_test, y_pred)}")
    print(f"\n F1 Score: {f1_score(y_test, y_pred)}")
# Out:
# ==========Logistic Regression===========
#
#  Accuaracy: 0.9694915254237289
#
#  Precision: 0.9655172413793104
#
#  Recall: 0.9333333333333333
#
#  F1 Score: 0.9491525423728814
#
# ==========Decision Tree Classifier===========
#
#  Accuaracy: 0.9152542372881356
#
#  Precision: 0.8350515463917526
#
#  Recall: 0.9
#
#  F1 Score: 0.8663101604278075
#
# ==========RandomForestClassifier===========
#
#  Accuaracy: 0.9661016949152542
#
#  Precision: 0.9651162790697675
#
#  Recall: 0.9222222222222223
#
#  F1 Score: 0.9431818181818182

# %%
model=LogisticRegression()

# %%
model.fit(x_train,y_train)
y_pred=model.predict(x_test)

# %%
print(f"\n Accuaracy: {accuracy_score(y_test, y_pred)}")
print(f"\n Precision: {precision_score(y_test, y_pred)}")
print(f"\n Recall: {recall_score(y_test, y_pred)}")
print(f"\n F1 Score: {f1_score(y_test, y_pred)}")
# Out:
#  Accuaracy: 0.9694915254237289
#
#  Precision: 0.9655172413793104
#
#  Recall: 0.9333333333333333
#
#  F1 Score: 0.9491525423728814

# %%
import joblib

# %%
joblib.dump(model, "credit_card_model.pkl")
# Out:
# ['credit_card_model.pkl']

# %%
model = joblib.load("credit_card_model.pkl")

# %%
pred = model.predict([[-1.3598071336738,-0.0727811733098497,2.53634673796914,1.37815522427443,-0.338320769942518,0.462387777762292,0.239598554061257,0.0986979012610507,0.363786969611213,0.0907941719789316,-0.551599533260813,-0.617800855762348,-0.991389847235408,-0.311169353699879,1.46817697209427,-0.470400525259478,0.207971241929242,0.0257905801985591,0.403992960255733,0.251412098239705,-0.018306777944153,0.277837575558899,-0.110473910188767,0.0669280749146731,0.128539358273528,-0.189114843888824,0.133558376740387,-0.0210530534538215,149.62]])
# Out:
# c:\Users\akash\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
pred[0]
# Out:
# np.int64(1)

# %%
if pred[0] == 0:
    print("Normal Transcation")
else:
    print("Fraud Transcation")
# Out:
# Fraud Transcation
